# %%
import numpy as np
import pandas as pd
import sys
import difflib

# %%
# file1 = sys.argv[1]
# file2 = sys.argv[2]
# result = sys.argv[3]
file1 = 'movie_list.txt'
file2 = 'movie_ratings.csv'
result = 'output.csv'

# %%
def to_new_line(data):
    return data.rstrip()
func_newline = np.vectorize(to_new_line)

# %%
name_list = pd.DataFrame(open(file1).readlines(), columns=['name']).apply(func_newline)

# %%
rate_list = pd.read_csv(file2)

# %%
def match(data):
    new_data = difflib.get_close_matches(data, name_list['name'])
    if len(new_data) != 0:
        return new_data[0]
    else:
        return None
func_match = np.vectorize(match)

# %%
rate_list['title'] = rate_list['title'].apply(func_match)

# %%
rate_list = rate_list.dropna()

# %%
rate_list = rate_list.groupby('title').mean().round(2)

# %%
rate_list.to_csv(result)
rate_list
# Out:
#                                     rating
# title
# 28 Days Later...                      7.18
# A Time to Kill                        7.92
# Anomalisa                             7.50
# Central Intelligence                  6.88
# Dead Poets Society                    8.33
# Detachment                            8.14
# Dial M for Murder                     8.12
# Dog Day Afternoon                     8.60
# El cuerpo                             8.44
# Everest                               7.07
# Everybody Wants Some!!                6.88
# Garden State                          8.67
# God Bless America                     7.50
# Heaven Is for Real                    6.12
# Hitman: Agent 47                      5.50
# House at the End of the Street        5.95
# I Spit on Your Grave 2                6.23
# Intouchables                          8.93
# Jûsan-nin no shikaku                  8.00
# Love Actually                         8.00
# Macbeth                               7.17
# Madagascar 3: Europe's Most Wanted    6.67
# Maleficent                            7.57
# Man on Fire                           8.44
# Maps to the Stars                     5.86
# Me Before You                         7.59
# Mrs. Doubtfire                        8.50
# Much Ado About Nothing                7.55
# Neighbors 2: Sorority Rising          5.35
# Non-Stop                              7.23
# P.S. I Love You                       6.50
# Paul Blart: Mall Cop 2                5.60
# Pitch Perfect 2                       7.27
# Poltergeist                           8.20
# Real Steel                            8.20
# Shaun the Sheep Movie                 7.21
# Sightseers                            6.67
# Sunshine                              7.50
# Texas Chainsaw 3D                     5.19
# The End of the Tour                   7.12
# The Life of David Gale                8.40
# To the Wonder                         5.89
# Tower Heist                           6.20
# Tyler Perry's Temptation              5.00
# Vaiana                                8.00
# War of the Worlds                     8.17
# Welcome to Me                         6.00
# Why Him?                              6.36
# Wreck-It Ralph                        7.83
